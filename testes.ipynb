# %%
from scoperty_utils import save_df_parquet,read_source_parquet,upsert_df
import pandas as pd
import datetime as dt


today = dt.date.today()

path = f'historyZone/scoperty-{str(today)}.parquet.gzip'

new_data = read_source_parquet(path)
new_data
# Out:
#            city    neighborhood  zip_code           street_name street_number  \
# 0        lopppp     Ludwigsfeld     90478        Schanzenstraße            13
# 1        London     Ludwigsfeld     90478        Schanzenstraße            13
# 2       Munchen     Ludwigsfeld     90478        Schanzenstraße            13
# 3      Nürnberg     Ludwigsfeld     90478        Schanzenstraße            13
# 4      Nürnberg  Marienvorstadt     90402            Hadermühle             6
# ...         ...             ...       ...                   ...           ...
# 9998   Nürnberg           Buch      90427  Höfleser Hauptstraße            77
# 9999   Nürnberg       Fischbach     90475              Am Brand             2
# 10000  Nürnberg    St. Leonhard     90439  Schneppenhorststraße            11
# 10001  Nürnberg    Gaismannshof     90431  Dechsendorfer Straße            19
# 10002  Nürnberg          Maiach     90451            Isarstraße            12
#
#        floor floor_location  door        property_type construction_date  ...  \
# 0        NaN           None   NaN   multi_family_house        2014-02-09  ...
# 1        NaN           None   NaN   multi_family_house        2014-02-09  ...
# 2        NaN           None   NaN   multi_family_house        2014-02-09  ...
# 3        NaN           None   NaN   multi_family_house        2014-02-09  ...
# 4        NaN           None   NaN   multi_family_house        1987-10-19  ...
# ...      ...            ...   ...                  ...               ...  ...
# 9998     NaN           None   NaN  single_family_house        1978-10-05  ...
# 9999     NaN           None   NaN  single_family_house        2033-03-18  ...
# 10000    NaN           None   NaN   multi_family_house        1969-04-22  ...
# 10001    NaN           None   NaN  single_family_house        1932-11-19  ...
# 10002    NaN           None   NaN  single_family_house        1984-09-04  ...
#
#       heating_type  has_energy_certificate  has_garage  has_parking  \
# 0             None                    None        None        False
# 1             None                    None        None        False
# 2             None                    None        None        False
# 3             None                    None        None        False
# 4             None                    None        None        False
# ...            ...                     ...         ...          ...
# 9998          None                    None        None        False
# 9999          None                    None        None         True
# 10000         None                    None        None        False
# 10001         None                    None        None        False
# 10002         None                    None        None        False
#
#        has_balcony        price        lon        lat  \
# 0             None  999999999.0  11.099906  49.446582
# 1             None  999999999.0  11.099906  49.446582
# 2             None  999999999.0  11.099906  49.446582
# 3             None  999999999.0  11.099906  49.446582
# 4             None          1.0  11.088089  49.450603
# ...            ...          ...        ...        ...
# 9998          None     448825.0  11.029574  49.488530
# 9999          None     768056.0  11.181802  49.427282
# 10000         None     332840.0  11.042111  49.439460
# 10001         None     405447.0  11.035186  49.450694
# 10002         None     752959.0  11.060945  49.408638
#
#                  processing_date  construction_year
# 0     2022-01-31 18:39:33.973226               2014
# 1     2022-01-31 18:39:33.973226               2014
# 2     2022-01-31 18:39:33.973226               2014
# 3     2022-01-31 18:39:33.973226               2014
# 4     2022-01-31 18:39:33.973226               1987
# ...                          ...                ...
# 9998  2022-01-31 18:39:33.973226               1978
# 9999  2022-01-31 18:39:33.973226               2033
# 10000 2022-01-31 18:39:33.973226               1969
# 10001 2022-01-31 18:39:33.973226               1932
# 10002 2022-01-31 18:39:33.973226               1984
#
# [10003 rows x 32 columns]

# %%
try:
        current_data = read_source_parquet(f'consumerZone/scoperty-properties.parquet.gzip')
    except:
        current_data = None

    def select_columns(df:pd.DataFrame):
            selected_columns = df[[
                    "city",
                    "neighborhood",
                    "zip_code",
                    "street_name",
                    "street_number",
                    "property_type",
                    "construction_date",
                    "number_of_units",
                    "living_area",
                    "total_area",
                    "has_parking",
                    "price",
                    "lon",
                    "lat"
                    ]]
            return selected_columns

    new_data = select_columns(new_data)

    merged = upsert_df(new_data,current_data,["city", "neighborhood", "zip_code", "street_name","street_number"])

    save_df_parquet(merged,'consumerZone','scoperty-properties')
